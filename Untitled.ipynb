# %%
from sympy import symbols, Function, Derivative, simplify, Eq, sqrt, collect, solve, expand, Rational

# Define symbolic variables
t = symbols('t', real=True)
T = Function('T')(t)          # T(t)
f = Function('f')(T)          # f(T)
rho = Function('rho')(t)      # rho(t)

# Parameters (can be defined later)
omega, omega_omega = symbols('omega omega_omega', real=True)
H = sqrt(Rational(3,2) * T)   # Hubble parameter H(T)
f_T = f.diff(T)
f_TT = f_T.diff(T)
dT = Derivative(T, t)         # T dot
H_dot = Derivative(H, t)      # H dot

# Express H_dot in terms of T and T_dot: H = sqrt(3/2 T)
# So H_dot = d/dt [sqrt(3/2 T)] = (1/2) * (3/2)/sqrt(3/2 T) * T_dot
H_dot_expr = simplify(Derivative(H, t).doit().subs(Derivative(T, t), dT).doit())
# H_dot_expr.subs(H, dT)
H_dot_expr
# Out:
# sqrt(6)*Derivative(T(t), t)/(4*sqrt(T(t)))

# %%
# === Equation (1): Energy density ===
eq1 = Eq(f/2 - T * f_T, -rho)

# === Equation (2): Dynamical equation ===
lhs_eq2 = 2*f - 3*dT*H*f_TT - 3*f_T*(H_dot_expr + H**2)
rhs_eq2 = (3*omega + omega_omega)*rho
eq2 = Eq(lhs_eq2, rhs_eq2)

# %%
# === Step 1: Solve Eq(1) for f ===
f_expr = solve(eq1, f)[0]  # f = 2(T f_T - rho)

# %%
# === Step 2: Substitute f into Eq(2) ===
lhs_eq2_sub = lhs_eq2.subs(f, f_expr)
eq2_substituted = Eq(lhs_eq2_sub, rhs_eq2)

# %%
# Simplify the equation
eq2_simplified = simplify(eq2_substituted)

eq2_simplified

# %% [markdown]
# ---

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

# === Degree of power series T(t) ===
N = 2  # Change this to increase series order

# === Symbols ===
t = sp.Symbol('t', real=True)
T = sp.Symbol('T', real=True)  # T becomes the independent variable for f(T)
omega, omega_w = sp.symbols('omega omega_w', real=True)

f = sp.Function('f')(T)
f_T = sp.diff(f, T)
f_TT = sp.diff(f_T, T)

# Coefficients a0, a1, ..., aN
a = sp.symbols(f'a0:{N+1}', real=True)

# T(t) = a0 + a1*t + a2*t^2 + ...
T_t = sum(a[n] * t**n for n in range(N + 1))
T_dot = sp.diff(T_t, t)

# %%
T_t
# Out:
# a0 + a1*t + a2*t**2

# %%
T_dot
# Out:
# a1 + 2*a2*t

# %%
# H(t) = sqrt(3/2 * T(t))
H = sp.sqrt(sp.Rational(3, 2) * T_t)

# Solve T(t) = T for t symbolically
t_sol = sp.solve(sp.Eq(T_t, T), t)
t_sol
# Out:
# [(-a1 - sqrt(4*T*a2 - 4*a0*a2 + a1**2))/(2*a2),
#  (-a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/(2*a2)]

# %%
# Take absolute value of the first solution
t_T = sp.simplify(sp.Abs(t_sol[0]))
t_T
# Out:
# Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2)/2

# %%
# Substitute t(T) into H and T_dot
H_T = H.subs(t, t_T)
T_dot_T = T_dot.subs(t, t_T)

# Build LHS and RHS of the equation symbolically
lhs = (
    -sp.Rational(1, 2) * T * f_T
    - 3 * T_dot_T * H_T * f_TT
    - (3 / (2 * H_T)) * T_dot_T * f_T
)

rhs = (3 * omega + omega_w + 4) * (T * f_T - f / 2)

# Construct the symbolic equation without evaluating
ode = sp.Eq(lhs, rhs, evaluate=False)
ode
# Out:
# Eq(-T*Derivative(f(T), T)/2 - 3*(a1 + a2*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2))*Derivative(f(T), T)/(2*sqrt(3*a0/2 + 3*a1*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2)/4 + 3*a2*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2)**2/8)) - (3*a1 + 3*a2*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2))*sqrt(3*a0/2 + 3*a1*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2)/4 + 3*a2*Abs((a1 + sqrt(4*T*a2 - 4*a0*a2 + a1**2))/a2)**2/8)*Derivative(f(T), (T, 2)), (T*Derivative(f(T), T) - f(T)/2)*(3*omega + omega_w + 4))

# %%
# Solve the ODE symbolically for f(T)
solution = sp.dsolve(ode, f)
solution
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\gruntz.py:557, in mrv_leadterm(e, x)
#     556 try:
# --> 557     lt = f.leadterm(w, logx=logw)
#     558 except (NotImplementedError, PoleError, ValueError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3533, in Expr.leadterm(self, x, logx, cdir)
#    3532 if x in c.free_symbols:
# -> 3533     raise ValueError(filldedent("""
#    3534         cannot compute leadterm(%s, %s). The coefficient
#    3535         should have been free of %s but got %s""" % (self, x, x, c)))
#    3536 c = c.subs(d, log(x))
#
# ValueError:
# cannot compute leadterm(_w**4/(31104*a0**2*a1**2 +
# 62208*a0**2*a1*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2) +
# 31104*a0**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 31104*a0*a1**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2) +
# 77760*a0*a1**2*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 62208*a0*a1*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**3 +
# 15552*a0*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**4 +
# 7776*a1**4*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 23328*a1**3*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**3 +
# 25272*a1**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**4 +
# 11664*a1*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**5 +
# 1944*a2**4*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**6), _w).
# The coefficient should have been free of _w but got
# _w**4/(31104*a0**2*a1**2 + 62208*a0**2*a1*a2*Abs(a1/a2 + sqrt(4*_w*a2
# - 4*a0*a2 + a1**2)/a2) + 31104*a0**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 31104*a0*a1**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2) + 77760*a0*a1**2*a2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 62208*a0*a1*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**3 + 15552*a0*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**4 + 7776*a1**4*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 23328*a1**3*a2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**3 + 25272*a1**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**4 + 11664*a1*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**5 + 1944*a2**4*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**6)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:1962, in Mul._eval_nseries(self, x, n, logx, cdir)
#    1961 for t in self.args:
# -> 1962     coeff, exp = t.leadterm(x)
#    1963     if not coeff.has(x):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3533, in Expr.leadterm(self, x, logx, cdir)
#    3532 if x in c.free_symbols:
# -> 3533     raise ValueError(filldedent("""
#    3534         cannot compute leadterm(%s, %s). The coefficient
#    3535         should have been free of %s but got %s""" % (self, x, x, c)))
#    3536 c = c.subs(d, log(x))
#
# ValueError:
# cannot compute leadterm(1/(31104*a0**2*a1**2 +
# 62208*a0**2*a1*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2) +
# 31104*a0**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 31104*a0*a1**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2) +
# 77760*a0*a1**2*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 62208*a0*a1*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**3 +
# 15552*a0*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**4 +
# 7776*a1**4*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**2 +
# 23328*a1**3*a2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**3 +
# 25272*a1**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**4 +
# 11664*a1*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**5 +
# 1944*a2**4*Abs(a1/a2 + sqrt(4*_w*a2 - 4*a0*a2 + a1**2)/a2)**6), _w).
# The coefficient should have been free of _w but got
# 1/(31104*a0**2*a1**2 + 62208*a0**2*a1*a2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2) + 31104*a0**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 31104*a0*a1**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2) + 77760*a0*a1**2*a2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 62208*a0*a1*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**3 + 15552*a0*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**4 + 7776*a1**4*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**2 + 23328*a1**3*a2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**3 + 25272*a1**2*a2**2*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**4 + 11664*a1*a2**3*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**5 + 1944*a2**4*Abs(a1/a2 + sqrt(4*_w*a2 -
# 4*a0*a2 + a1**2)/a2)**6)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Solve the ODE symbolically for f(T)
# ----> 2 solution = sp.dsolve(ode, f)
#       3 solution
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\ode.py:670, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     665 if simplify:
#     666     # odesimp() will attempt to integrate, if necessary, apply constantsimp(),
#     667     # attempt to solve for func, and apply any other hint specific
#     668     # simplifications
#     669     if isinstance(solvefunc, SingleODESolver):
# --> 670         sols = solvefunc.get_general_solution()
#     671     else:
#     672         sols = solvefunc(eq, func, order, match)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\single.py:283, in SingleODESolver.get_general_solution(self, simplify)
#     281     msg = "%s solver cannot solve:\n%s"
#     282     raise ODEMatchError(msg % (self.hint, self.ode_problem.eq))
# --> 283 return self._get_general_solution(simplify_flag=simplify)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\single.py:897, in Factorable._get_general_solution(self, simplify_flag)
#     895 for eq in eqns:
#     896     try:
# --> 897         sol = dsolve(eq, func(x))
#     898     except NotImplementedError:
#     899         continue
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\ode.py:640, in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     637 else:
#     638     # The key 'hint' stores the hint needed to be solved for.
#     639     hint = hints['hint']
# --> 640     return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\ode.py:672, in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     670     sols = solvefunc.get_general_solution()
#     671 else:
# --> 672     sols = solvefunc(eq, func, order, match)
#     673 if iterable(sols):
#     674     rv = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\solvers\ode\ode.py:2431, in ode_2nd_power_series_ordinary(eq, func, order, match)
#    2428         fact = term.args[0]
#    2429         series += (finaldict[term].subs([(recurr(0), C0), (recurr(1), C1)])*(
#    2430             x - x0)**fact)
# -> 2431 series = collect(expand_mul(series), [C0, C1]) + Order(x**terms)
#    2432 return Eq(f(x), series)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\decorators.py:236, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     234 if not isinstance(other, expectedcls):
#     235     return retval
# --> 236 return func(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\decorators.py:106, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     104         if f is not None:
#     105             return f(self)
# --> 106 return func(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:199, in Expr.__add__(self, other)
#     196 @sympify_return([('other', 'Expr')], NotImplemented)
#     197 @call_highest_priority('__radd__')
#     198 def __add__(self, other):
# --> 199     return Add(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\add.py:364, in Add.flatten(cls, seq)
#     361 for t in newseq:
#     362     for o in order_factors:
#     363         # x + O(x) -> O(x)
# --> 364         if o.contains(t):
#     365             t = None
#     366             break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\order.py:452, in Order.contains(self, expr)
#     449             if rv is not None:
#     450                 return rv
# --> 452 obj = self.func(expr, *self.args[1:])
#     453 return self.contains(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\order.py:230, in Order.__new__(cls, expr, *args, **kwargs)
#     228 elif expr:
#     229     try:
# --> 230         expr = expr.as_leading_term(*args)
#     231     except PoleError:
#     232         if isinstance(expr, Function) or\
#     233                 all(isinstance(arg, Function) for arg in expr.args):
#     234             # It is not possible to simplify an expression
#     235             # containing only functions (which raise error on
#     236             # call to leading term) further
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3490, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3488 if x not in self.free_symbols:
#    3489     return self
# -> 3490 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3491 if obj is not None:
#    3492     from sympy.simplify.powsimp import powsimp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:2036, in Mul._eval_as_leading_term(self, x, logx, cdir)
#    2035 def _eval_as_leading_term(self, x, logx=None, cdir=0):
# -> 2036     return self.func(*[t.as_leading_term(x, logx=logx, cdir=cdir) for t in self.args])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3490, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3488 if x not in self.free_symbols:
#    3489     return self
# -> 3490 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3491 if obj is not None:
#    3492     from sympy.simplify.powsimp import powsimp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\add.py:1055, in Add._eval_as_leading_term(self, x, logx, cdir)
#    1053             min = order
#    1054             new_expr = term
# -> 1055         elif min in order:
#    1056             new_expr += term
#    1058 except TypeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\order.py:456, in Order.__contains__(self, other)
#     455 def __contains__(self, other):
# --> 456     result = self.contains(other)
#     457     if result is None:
#     458         raise TypeError('contains did not evaluate to a bool')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\order.py:428, in Order.contains(self, expr)
#     426 for s in common_symbols:
#     427     from sympy.series.limits import Limit
# --> 428     l = Limit(ratio, s, point).doit(heuristics=False)
#     429     if not isinstance(l, Limit):
#     430         l = l != 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\limits.py:375, in Limit.doit(self, **hints)
#     372 l = None
#     374 try:
# --> 375     r = gruntz(e, z, z0, dir)
#     376     if r is S.NaN or l is S.NaN:
#     377         raise PoleError()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\gruntz.py:733, in gruntz(e, z, z0, dir)
#     730     else:
#     731         raise NotImplementedError("dir must be '+' or '-'")
# --> 733 r = limitinf(e0, z)
#     735 # This is a bit of a heuristic for nice results... we always rewrite
#     736 # tractable functions in terms of familiar intractable ones.
#     737 # It might be nicer to rewrite the exactly to what they were initially,
#     738 # but that would take some work to implement.
#     739 return r.rewrite('intractable', deep=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\gruntz.py:453, in limitinf(e, x)
#     451     c0, e0 = mrv_leadterm(e.min, x)
#     452 else:
# --> 453     c0, e0 = mrv_leadterm(e, x)
#     454 sig = sign(e0, x)
#     455 if sig == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\series\gruntz.py:563, in mrv_leadterm(e, x)
#     561 incr = S.One
#     562 while _series.is_Order:
# --> 563     _series = f._eval_nseries(w, n=n0+incr, logx=logw)
#     564     incr *= 2
#     565 series = _series.expand().removeO()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:1986, in Mul._eval_nseries(self, x, n, logx, cdir)
#    1984 if n0.is_nonnegative:
#    1985     n0 = S.Zero
# -> 1986 facs = [t.nseries(x, n=ceiling(n-n0), logx=logx, cdir=cdir) for t in self.args]
#    1987 from sympy.simplify.powsimp import powsimp
#    1988 res = powsimp(self.func(*facs).expand(), combine='exp', deep=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3396, in Expr.nseries(self, x, x0, n, dir, logx, cdir)
#    3394     return self.series(x, x0, n, dir, cdir=cdir)
#    3395 else:
# -> 3396     return self._eval_nseries(x, n=n, logx=logx, cdir=cdir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\power.py:1576, in Pow._eval_nseries(self, x, n, logx, cdir)
#    1573     return res
#    1575 try:
# -> 1576     c, d = g.leadterm(x, logx=logx)
#    1577 except (ValueError, NotImplementedError):
#    1578     if limit(g/x**maxpow, x, 0) == 0:
#    1579         # g has higher order zero
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3527, in Expr.leadterm(self, x, logx, cdir)
#    3525 from .symbol import Dummy
#    3526 from sympy.functions.elementary.exponential import log
# -> 3527 l = self.as_leading_term(x, logx=logx, cdir=cdir)
#    3528 d = Dummy('logx')
#    3529 if l.has(log(x)):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3490, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3488 if x not in self.free_symbols:
#    3489     return self
# -> 3490 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3491 if obj is not None:
#    3492     from sympy.simplify.powsimp import powsimp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:2036, in Mul._eval_as_leading_term(self, x, logx, cdir)
#    2035 def _eval_as_leading_term(self, x, logx=None, cdir=0):
# -> 2036     return self.func(*[t.as_leading_term(x, logx=logx, cdir=cdir) for t in self.args])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3490, in Expr.as_leading_term(self, logx, cdir, *symbols)
#    3488 if x not in self.free_symbols:
#    3489     return self
# -> 3490 obj = self._eval_as_leading_term(x, logx=logx, cdir=cdir)
#    3491 if obj is not None:
#    3492     from sympy.simplify.powsimp import powsimp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\add.py:1080, in Add._eval_as_leading_term(self, x, logx, cdir)
#    1078 incr = S.One
#    1079 while res.is_Order:
# -> 1080     res = old._eval_nseries(x, n=n0+incr, logx=logx, cdir=cdir).cancel().powsimp().trigsimp()
#    1081     incr *= 2
#    1082 return res.as_leading_term(x, logx=logx, cdir=cdir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\add.py:507, in Add._eval_nseries(self, x, n, logx, cdir)
#     506 def _eval_nseries(self, x, n, logx, cdir=0):
# --> 507     terms = [t.nseries(x, n=n, logx=logx, cdir=cdir) for t in self.args]
#     508     return self.func(*terms)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3396, in Expr.nseries(self, x, x0, n, dir, logx, cdir)
#    3394     return self.series(x, x0, n, dir, cdir=cdir)
#    3395 else:
# -> 3396     return self._eval_nseries(x, n=n, logx=logx, cdir=cdir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:1972, in Mul._eval_nseries(self, x, n, logx, cdir)
#    1970 for t, m in ords:
#    1971     n1 = ceiling(n - n0 + (m if m.is_number else 0))
# -> 1972     s = t.nseries(x, n=n1, logx=logx, cdir=cdir)
#    1973     ns = s.getn()
#    1974     if ns is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3396, in Expr.nseries(self, x, x0, n, dir, logx, cdir)
#    3394     return self.series(x, x0, n, dir, cdir=cdir)
#    3395 else:
# -> 3396     return self._eval_nseries(x, n=n, logx=logx, cdir=cdir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\add.py:507, in Add._eval_nseries(self, x, n, logx, cdir)
#     506 def _eval_nseries(self, x, n, logx, cdir=0):
# --> 507     terms = [t.nseries(x, n=n, logx=logx, cdir=cdir) for t in self.args]
#     508     return self.func(*terms)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3396, in Expr.nseries(self, x, x0, n, dir, logx, cdir)
#    3394     return self.series(x, x0, n, dir, cdir=cdir)
#    3395 else:
# -> 3396     return self._eval_nseries(x, n=n, logx=logx, cdir=cdir)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:1997, in Mul._eval_nseries(self, x, n, logx, cdir)
#    1994 ords2 = [Add.make_args(factor) for factor in facs]
#    1996 for fac in product(*ords2):
# -> 1997     ords3 = [coeff_exp(term, x) for term in fac]
#    1998     coeffs, powers = zip(*ords3)
#    1999     power = sum(powers)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\mul.py:1950, in Mul._eval_nseries.<locals>.coeff_exp(term, x)
#    1949 def coeff_exp(term, x):
# -> 1950     lt = term.as_coeff_exponent(x)
#    1951     if lt[0].has(x):
#    1952         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\expr.py:3503, in Expr.as_coeff_exponent(self, x)
#    3500 """ ``c*x**e -> c,e`` where x can be any symbolic expression.
#    3501 """
#    3502 from sympy.simplify.radsimp import collect
# -> 3503 s = collect(self, x)
#    3504 c, p = s.as_coeff_mul(x)
#    3505 if len(p) == 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\simplify\radsimp.py:392, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     387     expr = expr.func(*[
#     388             collect(a, syms, func, True, exact, distribute_order_term)
#     389             for a in expr.args if a != o]) + o
#     390 elif expr.is_Mul:
#     391     return expr.func(*[
# --> 392         collect(term, syms, func, True, exact, distribute_order_term)
#     393         for term in expr.args])
#     394 elif expr.is_Pow:
#     395     b = collect(
#     396         expr.base, syms, func, True, exact, distribute_order_term)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\simplify\radsimp.py:425, in collect(expr, syms, func, evaluate, exact, distribute_order_term)
#     423     terms = list(reversed(terms))
#     424     small_first = not small_first
# --> 425 result = parse_expression(terms, symbol)
#     427 if result is not None:
#     428     if not symbol.is_commutative:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\simplify\radsimp.py:317, in collect.<locals>.parse_expression(terms, pattern)
#     312 def parse_expression(terms, pattern):
#     313     """Parse terms searching for a pattern.
#     314     Terms is a list of tuples as returned by parse_terms;
#     315     Pattern is an expression treated as a product of factors.
#     316     """
# --> 317     pattern = Mul.make_args(pattern)
#     319     if len(terms) < len(pattern):
#     320         # pattern is longer than matched product
#     321         # so no chance for positive parsing result
#     322         return None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\operations.py:451, in AssocOp.make_args(cls, expr)
#     449     return expr.args
#     450 else:
# --> 451     return (sympify(expr),)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\sympify.py:374, in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     100 """
#     101 Converts an arbitrary expression to a type that can be used inside SymPy.
#     102
#    (...)
#     364
#     365 """
#     366 # XXX: If a is a Basic subclass rather than instance (e.g. sin rather than
#     367 # sin(x)) then a.__sympy__ will be the property. Only on the instance will
#     368 # a.__sympy__ give the *value* of the property (True). Since sympify(sin)
#    (...)
#     372 #
#     373 # https://github.com/sympy/sympy/issues/20124
# --> 374 is_sympy = getattr(a, '__sympy__', None)
#     375 if is_sympy is True:
#     376     return a
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sympy\core\basic.py:178, in Basic.__sympy__(self)
#     175 _args: tuple[Basic, ...]
#     176 _mhash: int | None
# --> 178 @property
#     179 def __sympy__(self):
#     180     return True
#     182 def __init_subclass__(cls):
#     183     # Initialize the default_assumptions FactKB and also any assumptions
#     184     # property methods. This method will only be called for subclasses of
#     185     # Basic but not for Basic itself so we call
#     186     # _prepare_class_assumptions(Basic) below the class definition.
#
# KeyboardInterrupt:

# %%
clean_sol = solution.rhs.removeO()
collected_sol = sp.collect(clean_sol, [omega, omega_w])
collected_sol

# %%
# Optional: plot with numerical values
subs_vals = {
    omega: 0,
    omega_w: 0,
    a[0]: 1.0,
    a[1]: 0.5,
    a[2]: 0.1
}

f_func = sp.lambdify(T, collected_sol.subs(subs_vals), 'numpy')

T_vals = np.linspace(1.1, 5, 400)
f_vals = f_func(T_vals)

plt.plot(T_vals, f_vals, label=r'$f(T)$')
plt.xlabel(r'$T$')
plt.ylabel(r'$f(T)$')
plt.title('Symbolic $f(T)$ with substituted parameters')
plt.grid(True)
plt.legend()
plt.show()
